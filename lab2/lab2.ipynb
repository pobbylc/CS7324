# %% [markdown]
# # Lab Two: Exploring Image Data
# ## Team members:

# %%
import pandas as pd
import numpy as np

team = pd.DataFrame()
team['name'] = ['Junaho Shen', 'Qinan Wang','Yuchong Chen']
team['ID'] = ['48058365','48098262','48029817']
team['email'] = ['junhaos@smu.edu','qinanw@smu.edu','yuchongc@smu.edu']
team
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>ID</th>
#       <th>email</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Junaho Shen</td>
#       <td>48058365</td>
#       <td>junhaos@smu.edu</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Qinan Wang</td>
#       <td>48098262</td>
#       <td>qinanw@smu.edu</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Yuchong Chen</td>
#       <td>48029817</td>
#       <td>yuchongc@smu.edu</td>
#     </tr>
#   </tbody>
# </table>
# </div>
